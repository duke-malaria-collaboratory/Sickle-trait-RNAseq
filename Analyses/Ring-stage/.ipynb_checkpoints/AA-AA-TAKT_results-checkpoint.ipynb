# %%
# %run ../../utilities/utilities.py

# %%
# just Ring stage genes (peak expression at or before 24 hours)
AA_AA_TAKT_results = pd.read_csv("Results/AA-AA-Results/kt_diss_AA_3D7_1stage_periodic_jtk05-AA_FUP_1stage_periodic_jtk05.tsv", 
                                     sep="\t", comment="#", index_col=0)

# %%
time_points = list(range(3, 51,3))
AA_3D7_1stage_periodic_ts_df = pd.read_csv("Data/AA_3D7_1stage_periodic_jtk05.txt", sep="\t", index_col=0)
AA_3D7_1stage_periodic_ts_df.columns = time_points
# AS_3D7_1stage_periodic_ts_df = pd.read_csv("Data/AS_3D7_1stage_periodic_jtk05.txt", sep="\t", index_col=0)
# AS_3D7_1stage_periodic_ts_df.columns = time_points
AA_FUP_1stage_periodic_ts_df = pd.read_csv("Data/AA_FUP_1stage_periodic_jtk05.txt", sep="\t", index_col=0)
AA_FUP_1stage_periodic_ts_df.columns = time_points
# AS_FUP_1stage_periodic_ts_df = pd.read_csv("Data/AS_FUP_1stage_periodic_jtk05.txt", sep="\t", index_col=0)
# AS_FUP_1stage_periodic_ts_df.columns = time_points

# %%
AA_AA_shifted_genes = AA_AA_TAKT_results[(AA_AA_TAKT_results["est_delay"] > 0.0) & (AA_AA_TAKT_results["kt_diss_pval"] <= 0.05)]

# %%
AA_AA_shifted_genes.sort_values(by=['est_delay'])
# Out:
#                 shift_0   shift_1   shift_2   shift_3   shift_4   shift_5  \
# PF3D7_1138600  0.150000  0.276190  0.395604  0.538462  0.696970  0.836364
# PF3D7_1134800  0.208333  0.323810  0.439560  0.512821  0.636364  0.800000
# PF3D7_1453900  0.191667  0.133333  0.109890  0.128205  0.090909  0.109091
# PF3D7_0529900  0.200000  0.238095  0.318681  0.384615  0.469697  0.563636
# PF3D7_0506200  0.200000  0.323810  0.263736  0.282051  0.393939  0.472727
# ...                 ...       ...       ...       ...       ...       ...
# PF3D7_1359500  0.208333  0.104762  0.131868  0.128205  0.075758  0.072727
# PF3D7_1353100  0.158333  0.180952  0.208791  0.256410  0.348485  0.418182
# PF3D7_0412400  0.166667  0.228571  0.318681  0.346154  0.439394  0.545455
# PF3D7_1244500  0.200000  0.266667  0.362637  0.384615  0.484848  0.563636
# PF3D7_0302300  0.141667  0.123810  0.153846  0.166667  0.212121  0.254545
#
#                 shift_6   shift_7   shift_8   shift_9  ...  shift_11  \
# PF3D7_1138600  0.866667  0.666667  0.571429  0.428571  ...       0.0
# PF3D7_1134800  0.888889  0.777778  0.642857  0.380952  ...       0.0
# PF3D7_1453900  0.111111  0.138889  0.178571  0.238095  ...       0.0
# PF3D7_0529900  0.688889  0.750000  0.821429  0.761905  ...       0.3
# PF3D7_0506200  0.511111  0.527778  0.464286  0.571429  ...       0.4
# ...                 ...       ...       ...       ...  ...       ...
# PF3D7_1359500  0.133333  0.111111  0.107143  0.190476  ...       0.3
# PF3D7_1353100  0.511111  0.638889  0.642857  0.666667  ...       0.8
# PF3D7_0412400  0.622222  0.777778  0.750000  0.952381  ...       0.9
# PF3D7_1244500  0.622222  0.750000  0.607143  0.619048  ...       0.3
# PF3D7_0302300  0.333333  0.388889  0.464286  0.571429  ...       0.5
#
#                shift_12  shift_13  shift_14  kt_diss_range  kt_diss  \
# PF3D7_1138600  0.500000  1.000000       1.0       1.000000      0.0
# PF3D7_1134800  0.166667  0.333333       1.0       1.000000      0.0
# PF3D7_1453900  0.166667  0.333333       1.0       1.000000      0.0
# PF3D7_0529900  0.000000  0.000000       0.0       0.821429      0.0
# PF3D7_0506200  0.000000  0.666667       1.0       1.000000      0.0
# ...                 ...       ...       ...            ...      ...
# PF3D7_1359500  0.500000  1.000000       0.0       1.000000      0.0
# PF3D7_1353100  0.666667  0.666667       0.0       0.800000      0.0
# PF3D7_0412400  0.666667  0.666667       0.0       0.952381      0.0
# PF3D7_1244500  0.500000  0.333333       0.0       0.750000      0.0
# PF3D7_0302300  0.833333  0.333333       0.0       0.833333      0.0
#
#                kt_diss_pval  est_delay  min_dist_flag  min_pval_flag
# PF3D7_1138600           0.0       33.0            0.0            0.0
# PF3D7_1134800           0.0       33.0            0.0            0.0
# PF3D7_1453900           0.0       33.0            0.0            0.0
# PF3D7_0529900           0.0       36.0            0.0            0.0
# PF3D7_0506200           0.0       36.0            0.0            0.0
# ...                     ...        ...            ...            ...
# PF3D7_1359500           0.0       42.0            0.0            0.0
# PF3D7_1353100           0.0       42.0            0.0            0.0
# PF3D7_0412400           0.0       42.0            0.0            0.0
# PF3D7_1244500           0.0       42.0            0.0            0.0
# PF3D7_0302300           0.0       42.0            0.0            0.0
#
# [216 rows x 21 columns]

# %%
gene_name = "PF3D7_1138600"
gene_df = pd.concat([AA_3D7_1stage_periodic_ts_df[AA_3D7_1stage_periodic_ts_df.index == gene_name],
                             AA_FUP_1stage_periodic_ts_df[AA_FUP_1stage_periodic_ts_df.index == gene_name]])
gene_df.index = [gene_name + "_AA_3D7", gene_name + "_AA_FUP"]
gene_df.reset_index(inplace=True)
gene_df.rename(columns={"index": "gene"}, inplace=True)
gene_df = pd.melt(gene_df, id_vars="gene", value_name="TPM", var_name="Hours")
sns.lineplot(x="Hours", y="TPM", hue="gene", data=gene_df)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(8, 7))
AA_3D7_heat = heatmap_max(AA_3D7_1stage_periodic_ts_df, AA_AA_shifted_genes.index.tolist(), 24,  axis=ax1)
ax1.title.set_text('AA 3D7 Periodic Genes\n({} genes)'.format(len(AA_3D7_heat)))
AA_FUP_heat = heatmap_order(AA_FUP_1stage_periodic_ts_df, AA_3D7_heat.tolist(), axis=ax2)
ax2.title.set_text('AA FUP Periodic Genes\n(AA 3D7 order: {} genes)'.format(len(AA_FUP_heat)))
