# %%
# %run ../../utilities/utilities.py

# %%
# just Ring stage genes (peak expression at or before 24 hours)
AA_AS_3D7_TAKT_results = pd.read_csv("Results/AA-AS-3D7-Results/kt_diss_AS_3D7_1stage_periodic_jtk05-AA_3D7_1stage_periodic_jtk05.tsv", 
                                     sep="\t", comment="#", index_col=0)

# %%
time_points = list(range(3, 51,3))
AA_3D7_1stage_periodic_ts_df = pd.read_csv("Data/AA_3D7_1stage_periodic_jtk05.txt", sep="\t", index_col=0)
AA_3D7_1stage_periodic_ts_df.columns = time_points
AS_3D7_1stage_periodic_ts_df = pd.read_csv("Data/AS_3D7_1stage_periodic_jtk05.txt", sep="\t", index_col=0)
AS_3D7_1stage_periodic_ts_df.columns = time_points
# AA_FUP_1stage_periodic_ts_df = pd.read_csv("Data/AA_FUP_1stage_periodic_jtk05.txt", sep="\t", index_col=0)
# AA_FUP_1stage_periodic_ts_df.columns = time_points
# AS_FUP_1stage_periodic_ts_df = pd.read_csv("Data/AS_FUP_1stage_periodic_jtk05.txt", sep="\t", index_col=0)
# AS_FUP_1stage_periodic_ts_df.columns = time_points

# %%
AA_AS_3D7_shifted_genes = AA_AS_3D7_TAKT_results[(AA_AS_3D7_TAKT_results["est_delay"] > 0.0) & (AA_AS_3D7_TAKT_results["kt_diss_pval"] <= 0.05)]

# %%
AA_AS_3D7_shifted_genes
# Out:
#                 shift_0   shift_1   shift_2   shift_3   shift_4   shift_5  \
# PF3D7_1361100  0.066667  0.114286  0.197802  0.243590  0.318182  0.381818
# PF3D7_0223300  0.133333  0.152381  0.219780  0.269231  0.333333  0.400000
# PF3D7_0909900  0.125000  0.314286  0.417582  0.500000  0.636364  0.763636
# PF3D7_1303400  0.200000  0.180952  0.186813  0.217949  0.303030  0.400000
# PF3D7_1018300  0.150000  0.152381  0.175824  0.217949  0.333333  0.400000
# ...                 ...       ...       ...       ...       ...       ...
# PF3D7_1328700  0.150000  0.190476  0.153846  0.128205  0.166667  0.236364
# PF3D7_0805500  0.050000  0.180952  0.285714  0.333333  0.439394  0.581818
# PF3D7_0526900  0.091667  0.219048  0.362637  0.448718  0.560606  0.654545
# PF3D7_0609900  0.058333  0.190476  0.307692  0.435897  0.590909  0.745455
# PF3D7_0615000  0.150000  0.200000  0.296703  0.358974  0.439394  0.509091
#
#                 shift_6   shift_7   shift_8   shift_9  ...  shift_11  \
# PF3D7_1361100  0.466667  0.527778  0.642857  0.809524  ...       0.7
# PF3D7_0223300  0.466667  0.500000  0.607143  0.619048  ...       0.9
# PF3D7_0909900  0.822222  0.805556  0.714286  0.619048  ...       0.5
# PF3D7_1303400  0.444444  0.555556  0.607143  0.571429  ...       0.7
# PF3D7_1018300  0.488889  0.416667  0.571429  0.571429  ...       0.7
# ...                 ...       ...       ...       ...  ...       ...
# PF3D7_1328700  0.133333  0.194444  0.357143  0.428571  ...       0.9
# PF3D7_0805500  0.733333  0.861111  0.892857  0.619048  ...       0.6
# PF3D7_0526900  0.733333  0.777778  0.750000  0.571429  ...       0.3
# PF3D7_0609900  0.955556  0.861111  0.750000  0.666667  ...       0.5
# PF3D7_0615000  0.555556  0.666667  0.750000  0.714286  ...       0.3
#
#                shift_12  shift_13  shift_14  kt_diss_range  kt_diss  \
# PF3D7_1361100  0.500000  0.333333       0.0       0.866667      0.0
# PF3D7_0223300  0.333333  0.000000       0.0       0.900000      0.0
# PF3D7_0909900  0.333333  0.000000       1.0       1.000000      0.0
# PF3D7_1303400  0.500000  0.000000       1.0       1.000000      0.0
# PF3D7_1018300  0.666667  0.000000       1.0       1.000000      0.0
# ...                 ...       ...       ...            ...      ...
# PF3D7_1328700  0.333333  0.000000       1.0       1.000000      0.0
# PF3D7_0805500  0.333333  0.000000       0.0       0.892857      0.0
# PF3D7_0526900  0.166667  0.000000       0.0       0.777778      0.0
# PF3D7_0609900  0.333333  0.000000       0.0       0.955556      0.0
# PF3D7_0615000  0.166667  0.000000       0.0       0.750000      0.0
#
#                kt_diss_pval  est_delay  min_dist_flag  min_pval_flag
# PF3D7_1361100           0.0       42.0            0.0            0.0
# PF3D7_0223300           0.0       39.0            0.0            0.0
# PF3D7_0909900           0.0       39.0            0.0            0.0
# PF3D7_1303400           0.0       39.0            0.0            0.0
# PF3D7_1018300           0.0       39.0            0.0            0.0
# ...                     ...        ...            ...            ...
# PF3D7_1328700           0.0       39.0            0.0            0.0
# PF3D7_0805500           0.0       39.0            0.0            0.0
# PF3D7_0526900           0.0       39.0            0.0            0.0
# PF3D7_0609900           0.0       39.0            0.0            0.0
# PF3D7_0615000           0.0       39.0            0.0            0.0
#
# [396 rows x 21 columns]

# %%
gene_name = "PF3D7_0223300"
gene_df = pd.concat([AA_3D7_1stage_periodic_ts_df[AA_3D7_1stage_periodic_ts_df.index == gene_name],
                             AS_3D7_1stage_periodic_ts_df[AS_3D7_1stage_periodic_ts_df.index == gene_name]])
gene_df.index = [gene_name + "_AA", gene_name + "_AS"]
gene_df.reset_index(inplace=True)
gene_df.rename(columns={"index": "gene"}, inplace=True)
gene_df = pd.melt(gene_df, id_vars="gene", value_name="TPM", var_name="Hours")
sns.lineplot(x="Hours", y="TPM", hue="gene", data=gene_df)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(8, 7))
AA_3D7_heat = heatmap_max(AA_3D7_1stage_periodic_ts_df, AA_AS_3D7_shifted_genes.index.tolist(), 24,  axis=ax1)
ax1.title.set_text('AA 3D7 Periodic Genes\n({} genes)'.format(len(AA_3D7_heat)))
AS_3D7_heat = heatmap_order(AS_3D7_1stage_periodic_ts_df, AA_3D7_heat.tolist(), axis=ax2)
ax2.title.set_text('AS 3D7 Periodic Genes\n(AA 3D7 order: {} genes)'.format(len(AS_3D7_heat)))
