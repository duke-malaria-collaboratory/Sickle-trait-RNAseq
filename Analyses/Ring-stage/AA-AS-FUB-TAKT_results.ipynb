# %%
# %run ../../utilities/utilities.py

# %%
# just Ring stage genes (peak expression at or before 24 hours)
AA_AS_FUB_TAKT_results = pd.read_csv("Results/AA-AS-FUB-Results/kt_diss_AS_FUP_1stage_periodic_jtk05-AA_FUP_1stage_periodic_jtk05.tsv", 
                                     sep="\t", comment="#", index_col=0)

# %%
time_points = list(range(3, 51,3))
# AA_3D7_1stage_periodic_ts_df = pd.read_csv("Data/AA_3D7_1stage_periodic_jtk05.txt", sep="\t", index_col=0)
# AA_3D7_1stage_periodic_ts_df.columns = time_points
# AS_3D7_1stage_periodic_ts_df = pd.read_csv("Data/AS_3D7_1stage_periodic_jtk05.txt", sep="\t", index_col=0)
# AS_3D7_1stage_periodic_ts_df.columns = time_points
AA_FUP_1stage_periodic_ts_df = pd.read_csv("Data/AA_FUP_1stage_periodic_jtk05.txt", sep="\t", index_col=0)
AA_FUP_1stage_periodic_ts_df.columns = time_points
AS_FUP_1stage_periodic_ts_df = pd.read_csv("Data/AS_FUP_1stage_periodic_jtk05.txt", sep="\t", index_col=0)
AS_FUP_1stage_periodic_ts_df.columns = time_points

# %%
AA_AS_FUB_shifted_genes = AA_AS_FUB_TAKT_results[(AA_AS_FUB_TAKT_results["est_delay"] > 0.0) & (AA_AS_FUB_TAKT_results["kt_diss_pval"] <= 0.05)]

# %%
AA_AS_FUB_shifted_genes[AA_AS_FUB_shifted_genes['est_delay'] < 45].head(n=20)
# Out:
#                 shift_0   shift_1   shift_2   shift_3   shift_4   shift_5  \
# PF3D7_1401500  0.200000  0.266667  0.395604  0.500000  0.636364  0.763636
# PF3D7_1462400  0.041667  0.057143  0.054945  0.064103  0.075758  0.090909
# PF3D7_1459600  0.116667  0.285714  0.406593  0.487179  0.606061  0.709091
# PF3D7_1103000  0.175000  0.123810  0.208791  0.205128  0.196970  0.181818
# PF3D7_1439300  0.150000  0.276190  0.406593  0.461538  0.560606  0.636364
# PF3D7_1420500  0.241667  0.361905  0.483516  0.666667  0.787879  0.927273
# PF3D7_0621350  0.158333  0.114286  0.208791  0.269231  0.272727  0.327273
# PF3D7_1210200  0.091667  0.047619  0.153846  0.217949  0.227273  0.272727
# PF3D7_1339200  0.183333  0.219048  0.208791  0.346154  0.303030  0.345455
# PF3D7_1213100  0.183333  0.257143  0.197802  0.269231  0.227273  0.327273
# PF3D7_1252000  0.175000  0.295238  0.219780  0.282051  0.348485  0.381818
# PF3D7_1301700  0.016667  0.114286  0.197802  0.256410  0.348485  0.454545
# PF3D7_0318300  0.083333  0.200000  0.340659  0.410256  0.484848  0.581818
# PF3D7_1232400  0.075000  0.161905  0.219780  0.282051  0.303030  0.400000
# PF3D7_0934600  0.083333  0.200000  0.318681  0.397436  0.484848  0.581818
# PF3D7_0917800  0.091667  0.142857  0.197802  0.205128  0.227273  0.272727
# PF3D7_1354800  0.050000  0.228571  0.406593  0.487179  0.590909  0.654545
# PF3D7_1232400  0.500000  0.666667       0.0       0.800000      0.0
# PF3D7_0934600  0.000000  0.000000       0.0       0.861111      0.0
# PF3D7_0917800  0.500000  0.000000       1.0       1.000000      0.0
# PF3D7_1354800  0.333333  0.666667       0.0       0.833333      0.0
# PF3D7_1463500  0.833333  0.333333       0.0       0.861111      0.0
# PF3D7_0220000  0.666667  0.000000       0.0       0.809524      0.0
# PF3D7_0713500  0.333333  0.666667       0.0       0.857143      0.0
#
#                kt_diss_pval  est_delay  min_dist_flag  min_pval_flag
# PF3D7_1401500           0.0       42.0            0.0            0.0
# PF3D7_1462400           0.0       42.0            0.0            0.0
# PF3D7_1459600           0.0       33.0            0.0            0.0
# PF3D7_1103000           0.0       42.0            0.0            0.0
# PF3D7_1439300           0.0       33.0            0.0            0.0
# PF3D7_1420500           0.0       42.0            0.0            0.0
# PF3D7_0621350           0.0       42.0            0.0            0.0
# PF3D7_1210200           0.0       42.0            0.0            0.0
# PF3D7_1339200           0.0       39.0            0.0            0.0
# PF3D7_1213100           0.0       42.0            0.0            0.0
# PF3D7_1252000           0.0       42.0            0.0            0.0
# PF3D7_1301700           0.0       42.0            0.0            0.0
# PF3D7_0318300           0.0       33.0            0.0            0.0
# PF3D7_1232400           0.0       42.0            0.0            0.0
# PF3D7_0934600           0.0       36.0            0.0            0.0
# PF3D7_0917800           0.0       39.0            0.0            0.0
# PF3D7_1354800           0.0       42.0            0.0            0.0
# PF3D7_1463500           0.0       42.0            0.0            0.0
# PF3D7_0220000           0.0       39.0            0.0            0.0
# PF3D7_0713500           0.0       42.0            0.0            0.0
#
# [20 rows x 21 columns]

# %%
gene_name = "PF3D7_1401500"
gene_df = pd.concat([AA_FUP_1stage_periodic_ts_df[AA_FUP_1stage_periodic_ts_df.index == gene_name],
                             AS_FUP_1stage_periodic_ts_df[AS_FUP_1stage_periodic_ts_df.index == gene_name]])
gene_df.index = [gene_name + "_AA", gene_name + "_AS"]
gene_df.reset_index(inplace=True)
gene_df.rename(columns={"index": "gene"}, inplace=True)
gene_df = pd.melt(gene_df, id_vars="gene", value_name="TPM", var_name="Hours")
sns.lineplot(x="Hours", y="TPM", hue="gene", data=gene_df)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(8, 7))
AA_FUP_heat = heatmap_max(AA_FUP_1stage_periodic_ts_df, AA_AS_FUB_shifted_genes.index.tolist(), 24,  axis=ax1)
ax1.title.set_text('AA FUP Periodic Genes\n({} genes)'.format(len(AA_FUP_heat)))
AS_FUP_heat = heatmap_order(AS_FUP_1stage_periodic_ts_df, AA_FUP_heat.tolist(), axis=ax2)
ax2.title.set_text('AS FUP Periodic Genes\n(AA FUP order: {} genes)'.format(len(AS_FUP_heat)))
