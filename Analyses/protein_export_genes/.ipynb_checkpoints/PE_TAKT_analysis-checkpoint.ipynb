# %%
# %run ../../utilities/utilities.py
# %run read_data_functions.ipynb

# %%
protein_export_gene_list = pe_gene_list()
AA13_3D7_df, AA17_3D7_df, AS15_3D7_df, AS16_3D7_df = get_ts_3D7()
AA13_FUP_df, AA17_FUP_df, AS18_FUP_df, AS19_FUP_df = get_ts_FUP()

# %%
AA13_3D7_AA17_3D7_takt, AA13_3D7_AS15_3D7_takt, AA13_3D7_AS16_3D7_takt, AA17_3D7_AS15_3D7_takt, AA17_3D7_AS16_3D7_takt = get_3D7_takt_pe_results()

# %%
AA13_FUP_AA17_FUP_takt, AA13_FUP_AS18_FUP_takt, AA13_FUP_AS19_FUP_takt, AA17_FUP_AS18_FUP_takt, AA17_FUP_AS19_FUP_takt = get_FUP_takt_pe_results()

# %%
def prep_df_for_plot(takt_df):
    new_takt_df = takt_df.reset_index()
    datasets = new_takt_df.columns[0]
    new_takt_df = new_takt_df[[datasets, 'kt_diss', 'kt_diss_pval', 'est_delay']]
    new_takt_df['datasets'] = datasets
    new_takt_df = new_takt_df.rename(columns={datasets: "gene"})
    return(new_takt_df)

def correct_est_delay(takt_df):
    corrected_takt_df = takt_df.copy()
    for index, row in corrected_takt_df.iterrows():
        est_delay = row[3]
        new_est_delay = 0
        if est_delay > 24.0:
            new_est_delay = est_delay - 24.0
            corrected_takt_df.at[index, 'est_delay'] = new_est_delay
    return(corrected_takt_df)

# %%
# 3D7 col drops for melting and plotting
sub_AA13_3D7_AA17_3D7_takt = correct_est_delay(prep_df_for_plot(AA13_3D7_AA17_3D7_takt))
sub_AA13_3D7_AS15_3D7_takt = correct_est_delay(prep_df_for_plot(AA13_3D7_AS15_3D7_takt))
sub_AA13_3D7_AS16_3D7_takt = correct_est_delay(prep_df_for_plot(AA13_3D7_AS16_3D7_takt))
sub_AA17_3D7_AS15_3D7_takt = correct_est_delay(prep_df_for_plot(AA17_3D7_AS15_3D7_takt))
sub_AA17_3D7_AS16_3D7_takt = correct_est_delay(prep_df_for_plot(AA17_3D7_AS16_3D7_takt))

# %%
# FUP col drops for melting and plotting
sub_AA13_FUP_AA17_FUP_takt = correct_est_delay(prep_df_for_plot(AA13_FUP_AA17_FUP_takt))
sub_AA13_FUP_AS18_FUP_takt = correct_est_delay(prep_df_for_plot(AA13_FUP_AS18_FUP_takt))
sub_AA13_FUP_AS19_FUP_takt = correct_est_delay(prep_df_for_plot(AA13_FUP_AS19_FUP_takt))
sub_AA17_FUP_AS18_FUP_takt = correct_est_delay(prep_df_for_plot(AA17_FUP_AS18_FUP_takt))
sub_AA17_FUP_AS19_FUP_takt = correct_est_delay(prep_df_for_plot(AA17_FUP_AS19_FUP_takt))

# %%
all_sub_takt_dfs = pd.concat([sub_AA13_3D7_AA17_3D7_takt, sub_AA13_3D7_AS15_3D7_takt, sub_AA13_3D7_AS16_3D7_takt,
                             sub_AA17_3D7_AS15_3D7_takt, sub_AA17_3D7_AS16_3D7_takt, sub_AA13_FUP_AA17_FUP_takt,
                             sub_AA13_FUP_AS18_FUP_takt, sub_AA13_FUP_AS19_FUP_takt, sub_AA17_FUP_AS18_FUP_takt,
                             sub_AA17_FUP_AS19_FUP_takt])

# %%
melt_all_sub_takt_dfs = all_sub_takt_dfs.melt(id_vars=['gene','datasets'], var_name='category')

# %%
melt_all_sub_takt_dfs
# Out:
#               gene             datasets   category      value
# 0    PF3D7_0202000  AA13 3D7 - AA17 3D7    kt_diss   0.008333
# 1    PF3D7_0500800  AA13 3D7 - AA17 3D7    kt_diss   0.000000
# 2    PF3D7_0201900  AA13 3D7 - AA17 3D7    kt_diss   0.000000
# 3    PF3D7_0935900  AA13 3D7 - AA17 3D7    kt_diss   0.091667
# 4    PF3D7_1353200  AA13 3D7 - AA17 3D7    kt_diss   0.050000
# ..             ...                  ...        ...        ...
# 295  PF3D7_0201900  AA17 FUP - AS19 FUP  est_delay  18.000000
# 296  PF3D7_1370300  AA17 FUP - AS19 FUP  est_delay   0.000000
# 297  PF3D7_0500800  AA17 FUP - AS19 FUP  est_delay   6.000000
# 298  PF3D7_0202000  AA17 FUP - AS19 FUP  est_delay  18.000000
# 299  PF3D7_0501300  AA17 FUP - AS19 FUP  est_delay   0.000000
#
# [300 rows x 4 columns]

# %%
est_delay = sns.catplot(x="gene", y="value", hue='datasets', jitter=0.2,
                data=melt_all_sub_takt_dfs[melt_all_sub_takt_dfs["category"] == 'est_delay'])
est_delay.set_xticklabels(rotation=90)
g=est_delay.fig.suptitle('Minimum KT distance estimated delay')

# %%
kt_diss_pval = sns.catplot(x="gene", y="value", hue='datasets', jitter=0.2,
                data=melt_all_sub_takt_dfs[melt_all_sub_takt_dfs["category"] == 'kt_diss_pval'])
kt_diss_pval.set_xticklabels(rotation=90)
g=kt_diss_pval.fig.suptitle('Minimum KT distance p-value')

# %%
kt_diss = sns.catplot(x="gene", y="value", hue='datasets', jitter=0.2,
                data=melt_all_sub_takt_dfs[melt_all_sub_takt_dfs["category"] == 'kt_diss'])
kt_diss.set_xticklabels(rotation=90)
g=kt_diss.fig.suptitle('Minimum KT distance')

# %%
sub_AA13_3D7_AS15_3D7_takt
# Out:
#             gene   kt_diss  kt_diss_pval  est_delay             datasets
# 0  PF3D7_0935900  0.054945        0.5980        6.0  AA13 3D7 - AS15 3D7
# 1  PF3D7_0501300  0.100000        0.6087        0.0  AA13 3D7 - AS15 3D7
# 2  PF3D7_0500800  0.000000        0.0000       18.0  AA13 3D7 - AS15 3D7
# 3  PF3D7_1149000  0.033333        0.6001        0.0  AA13 3D7 - AS15 3D7
# 4  PF3D7_1370300  0.033333        0.6062        0.0  AA13 3D7 - AS15 3D7
# 5  PF3D7_0201900  0.000000        0.0000       18.0  AA13 3D7 - AS15 3D7
# 6  PF3D7_0202000  0.025000        0.6006        0.0  AA13 3D7 - AS15 3D7
# 7  PF3D7_0936000  0.058333        0.6052        0.0  AA13 3D7 - AS15 3D7
# 8  PF3D7_1353200  0.041667        0.5999        0.0  AA13 3D7 - AS15 3D7
# 9  PF3D7_0102200  0.000000        0.0000       15.0  AA13 3D7 - AS15 3D7

# %%
# AA_AA_shifted_genes = AA_AA_TAKT_results[(AA_AA_TAKT_results["est_delay"] > 0.0) & (AA_AA_TAKT_results["kt_diss_pval"] <= 0.05)]

# %%
gene_name = "PF3D7_0935900"
gene_df = pd.concat([AA13_3D7_df[AA13_3D7_df.index == gene_name],
                             AS15_3D7_df[AS15_3D7_df.index == gene_name]])
gene_df.index = [gene_name + "_AA13_3D7", gene_name + "_AS15_3D7"]
gene_df.reset_index(inplace=True)
gene_df.rename(columns={"index": "gene"}, inplace=True)
gene_df = pd.melt(gene_df, id_vars="gene", value_name="TPM", var_name="Hours")
sns.lineplot(x="Hours", y="TPM", hue="gene", data=gene_df)

# %% [markdown]
# ## Heatmaps of dataset comparisons

# %% [markdown]
# ## 3D7

# %%
# AA13 AA17
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(6,4))
AA13_3D7_heat = heatmap_max(AA13_3D7_df, protein_export_gene_list, 16, axis=ax1, yticks=True)
ax1.title.set_text('AA13 3D7\nProtein Export Genes')
AA17_3D7_heat = heatmap_order(AA17_3D7_df, AA13_3D7_heat.tolist(), axis=ax2)
ax2.title.set_text('AA17 3D7\nProtein Export Genes\n(AA13 3D7 order)')

# %%
# AA13 AS15
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(6,4))
AA13_3D7_heat = heatmap_max(AA13_3D7_df, protein_export_gene_list, 16, axis=ax1, yticks=True)
ax1.title.set_text('AA13 3D7\nProtein Export Genes')
AS15_3D7_heat = heatmap_order(AS15_3D7_df, AA13_3D7_heat.tolist(), axis=ax2)
ax2.title.set_text('AS15 3D7\nProtein Export Genes\n(AA13 3D7 order)')

# %%
# AA13 AS16
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(6,4))
AA13_3D7_heat = heatmap_max(AA13_3D7_df, protein_export_gene_list, 16, axis=ax1, yticks=True)
ax1.title.set_text('AA13 3D7\nProtein Export Genes')
AS16_3D7_heat = heatmap_order(AS16_3D7_df, AA13_3D7_heat.tolist(), axis=ax2)
ax2.title.set_text('AS16 3D7\nProtein Export Genes\n(AA13 3D7 order)')

# %%
# AA17 AS15
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(6,4))
AA17_3D7_heat = heatmap_max(AA17_3D7_df, protein_export_gene_list, 16, axis=ax1, yticks=True)
ax1.title.set_text('AA17 3D7\nProtein Export Genes')
AS15_3D7_heat = heatmap_order(AS15_3D7_df, AA17_3D7_heat.tolist(), axis=ax2)
ax2.title.set_text('AS15 3D7\nProtein Export Genes\n(AA17 3D7 order)')

# %%
# AA17 AS16
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(6,4))
AA17_3D7_heat = heatmap_max(AA17_3D7_df, protein_export_gene_list, 16, axis=ax1, yticks=True)
ax1.title.set_text('AA17 3D7\nProtein Export Genes')
AS16_3D7_heat = heatmap_order(AS16_3D7_df, AA17_3D7_heat.tolist(), axis=ax2)
ax2.title.set_text('AS16 3D7\nProtein Export Genes\n(AA17 3D7 order)')

# %% [markdown]
# ## FUP

# %%
# AA13 AA17
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(6,4))
AA13_FUP_heat = heatmap_max(AA13_FUP_df, protein_export_gene_list, 16, axis=ax1, yticks=True)
ax1.title.set_text('AA13 FUP\nProtein Export Genes')
AA17_FUP_heat = heatmap_order(AA17_FUP_df, AA13_FUP_heat.tolist(), axis=ax2)
ax2.title.set_text('AA17 FUP\nProtein Export Genes\n(AA13 FUP order)')

# %%
# AA13 AS18
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(6,4))
AA13_FUP_heat = heatmap_max(AA13_FUP_df, protein_export_gene_list, 16, axis=ax1, yticks=True)
ax1.title.set_text('AA13 FUP\nProtein Export Genes')
AS18_FUP_heat = heatmap_order(AS18_FUP_df, AA13_FUP_heat.tolist(), axis=ax2)
ax2.title.set_text('AS18 FUP\nProtein Export Genes\n(AA13 FUP order)')

# %%
# AA13 AS19
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(6,4))
AA13_FUP_heat = heatmap_max(AA13_FUP_df, protein_export_gene_list, 16, axis=ax1, yticks=True)
ax1.title.set_text('AA13 FUP\nProtein Export Genes')
AS19_FUP_heat = heatmap_order(AS19_FUP_df, AA13_FUP_heat.tolist(), axis=ax2)
ax2.title.set_text('AS19 FUP\nProtein Export Genes\n(AA13 FUP order)')

# %%
# AA17 AS18
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(6,4))
AA17_FUP_heat = heatmap_max(AA17_FUP_df, protein_export_gene_list, 16, axis=ax1, yticks=True)
ax1.title.set_text('AA17 FUP\nProtein Export Genes')
AS18_FUP_heat = heatmap_order(AS18_FUP_df, AA17_FUP_heat.tolist(), axis=ax2)
ax2.title.set_text('AS18 FUP\nProtein Export Genes\n(AA17 FUP order)')

# %%
# AA17 AS19
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(6,4))
AA17_FUP_heat = heatmap_max(AA17_FUP_df, protein_export_gene_list, 16, axis=ax1, yticks=True)
ax1.title.set_text('AA17 FUP\nProtein Export Genes')
AS19_FUP_heat = heatmap_order(AS19_FUP_df, AA17_FUP_heat.tolist(), axis=ax2)
ax2.title.set_text('AS19 FUP\nProtein Export Genes\n(AA17 FUP order)')
